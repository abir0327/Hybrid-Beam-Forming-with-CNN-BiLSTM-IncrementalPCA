# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import h5py
filename = "/content/drive/MyDrive/mimo/FSRCNN_FULL_RUN_X_VehA_48_22.h5"

with h5py.File(filename, "r") as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("Keys: %s" % f.keys())
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]

    # get the object type for a_group_key: usually group or dataset
    print(type(f[a_group_key])) 

    # If a_group_key is a group name, 
    # this gets the object names in the group and returns as a list
    data = list(f[a_group_key])

    # If a_group_key is a dataset name, 
    # this gets the dataset values and returns as a list
    data = list(f[a_group_key])
    print(data)
    # preferred methods to get dataset values:
    #ds_obj = f[a_group_key]      # returns as a h5py dataset object
    #ds_arr = f[a_group_key][()]
# Out:
# Keys: <KeysViewHDF5 ['conv2d', 'conv2d_1', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_6', 'conv2d_transpose', 'input_1', 'p_re_lu', 'p_re_lu_1', 'p_re_lu_2', 'p_re_lu_3', 'p_re_lu_4', 'p_re_lu_5', 'p_re_lu_6']>
# <class 'h5py._hl.group.Group'>
# ['conv2d']

# %%
import numpy as np
array_nor3k32_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/32bs1pre.npy")
h32x= max(array_nor3k32_rpre_npy)
h32n= min(array_nor3k32_rpre_npy)
#for i in range(0,499):
z32= ((array_nor3k32_rpre_npy-h32n)/(h32x-h32n))
#print(z32)

# %%
import numpy as np
array_nor3k32_rop_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/32bs1op.npy")

h32= max(array_nor3k32_rop_npy)
acc32=array_nor3k32_rpre_npy/h32
#print(acc32)

# %%
import numpy as np
array_nor3k32_rloss_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/32bs1loss.npy")

# %%
z1=

# %%
import numpy as np
array_orpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/orpre.npy")
h16x= max(array_orpre_npy)
h16n= min(array_orpre_npy)
#z16= ((array_orpre_npy-h16n)/(h16x-h16n))

# %%
import numpy as np
array_orop_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/orop.npy")
h16= max(array_orop_npy)
#acc16=array_k16_rpre_npy/h16

# %%
import numpy as np
array_no12rop_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/noise12pre.npy")
h16= max(array_no12rop_npy)

# %%
import numpy as np
array_no22rop_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/noise22pre.npy")
h16= max(array_no22rop_npy)

# %%
import numpy as np
array_dislabrpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/dislabpre.npy")
h16= max(array_dislabrpre_npy)

# %%
import numpy as np
array_orloss_npy = np.load("/content/drive/MyDrive/HBF-Net-main/newres/orloss.npy")

# %%
import numpy as np
array_k4_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k4pre.npy")
k4= max(array_k4_rpre_npy)
#acc8=array_k8_rpre_npy/h8
#print(h8)

# %%
import numpy as np
array_k8_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k8pre.npy")
k8= max(array_k8_rpre_npy)
h8n= min(array_k8_rpre_npy)
#z8= ((array_k8_rpre_npy-h8n)/(h8x-h8n))

# %%
import numpy as np
array_k16_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k16pre.npy")
k16= max(array_k16_rpre_npy)

# %%
import numpy as np
array_k32_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/nor3_rpre.npy")
k32= max(array_k32_rpre_npy)

# %%
h5=np.array([k16,k4,k8,k32])
k5=np.array([4,8,16,32])
print(h5)
#h6=np.array([array_nor3k32_rpre_npy,array_k16_rpre_npy,array_k4_rpre_npy,array_k8_rpre_npy])
#print(type(array_k4_rpre_npy))
# Out:
# [4.007221  4.042865  4.063896  4.7993965]

# %%
import numpy as np
array_k8_rloss_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k8loss.npy")

# %%
import numpy as np
array_k4_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k4pre.npy")
h4x= max(array_k4_rpre_npy)
h4n= min(array_k4_rpre_npy)
z4= ((array_k4_rpre_npy-h4n)/(h4x-h4n))

# %%
import numpy as np
array_k4_rop_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k4op.npy")
h4= max(array_k4_rop_npy)
acc4=array_k4_rpre_npy/h4

# %%
import numpy as np
array_k4_rloss_npy = np.load("/content/drive/MyDrive/HBF-Net-main/k4loss.npy")

# %%
import numpy as np
array_noise1pre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/noise1_rpre.npy")
hn1x= max(array_noise1pre_npy)
hn1n= min(array_noise1pre_npy)
zn1= ((array_noise1pre_npy-hn1n)/(hn1x-hn1n))

# %%
import numpy as np
array_noise2pre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/noise2_rpre.npy")
hn2x= max(array_noise2pre_npy)
hn2n= min(array_noise2pre_npy)
zn2= ((array_noise2pre_npy-hn2n)/(hn2x-hn2n))

# %%
import numpy as np
array_noise3pre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/noise3_rpre.npy")
hn3x= max(array_noise3pre_npy)
hn3n= min(array_noise3pre_npy)
zn3= ((array_noise3pre_npy-hn3n)/(hn3x-hn3n))

# %%
import numpy as np
array_120dbpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/120db32pre.npy")
p120m= max(array_120dbpre_npy)

# %%
import numpy as np
array_125dbpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/125db32pre.npy")
p125m= max(array_125dbpre_npy)

# %%
import numpy as np
array_135dbpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/135db32pre.npy")
p135m= max(array_135dbpre_npy)

# %%
print(array_135dbpre_npy)
# Out:
# [1.4492247 2.599862 ]

# %%
p5=np.array([p135m,p120m,h16x])
snr5=np.array([120,125,130])
print(p5)
#h6=np.array([array_nor3k32_rpre_npy,array_k16_rpre_npy,array_k4_rpre_npy,array_k8_rpre_npy])
#print(type(array_k4_rpre_npy))
# Out:
# [2.599862  4.78316   4.9231973]

# %%
h5=np.array([h4,h8,h16,h32])
k5=np.array([4,8,16,32])
print(h5)
h6=np.array([array_nor3k32_rpre_npy,array_k16_rpre_npy,array_k4_rpre_npy,array_k8_rpre_npy])
print(type(array_k4_rpre_npy))
# Out:
# [0.9588949 1.247535  1.3504486 5.303135 ]
# <class 'numpy.ndarray'>

# %%
for i in range(1,500):
  t5=i
t6=np.array(t5)
t7=np.array([t6,t6,t6,t6])
print(type(t7))
t6.shape
# Out:
# <class 'numpy.ndarray'>
# ()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_nor3k32_rpre_npy,color='g')
  plt.plot(array_orpre_npy,color='b' )
  #plt.plot(array_k8_rpre_npy[5:500],color='y' )
  #plt.plot(array_k4_rpre_npy[5:500],color='r')
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for Different Path')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  plt.legend(['Single Path', 'Multiple Path'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/bs32vsor.png",  dpi=400)
  plt.show()

# %%
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_no12rop_npy,color='g')
  plt.plot(array_no22rop_npy,color='b' )
  #plt.plot(array_k8_rpre_npy[5:500],color='y' )
  #plt.plot(array_k4_rpre_npy[5:500],color='r')
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for Different Noise')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  #plt.legend(['', 'Multiple Path'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/no12vsno22.png",  dpi=400)
  plt.show()

# %%
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_dislabrpre_npy,color='g')
  #plt.plot(array_nor3k32_rpre_npy,color='b' )
  plt.plot(array_orpre_npy,color='r' )
  #plt.plot(array_k4_rpre_npy[5:500],color='r')
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for Different Places')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  plt.legend(['Indoor', 'Outdoor'], loc='upper right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/dislabvsor.png",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_noise1pre_npy[5:500])
  plt.plot(array_noise2pre_npy[5:500] )
  plt.plot(array_noise3pre_npy[5:500])
  #plt.plot(array_k4_rpre_npy)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for Noise')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  #plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/noise",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_k16_rpre_npy)
  plt.plot(array_k4_rpre_npy)
  plt.plot(array_k8_rpre_npy )
  
  plt.plot(array_k32_rpre_npy)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for Different RSSI')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/kup.png",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_120dbpre_npy[1:100])
  
  plt.plot(array_orpre_npy)
  #plt.plot(array_135dbpre_npy[1:100])
  plt.plot(array_125dbpre_npy[1:100])
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for Different Noise Power')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  plt.legend(['-σ²=120dB', '-σ²=125dB','-σ²=130dB'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/uppower.png",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(array_nor3k32_rloss_npy)
  plt.plot(array_k16_rloss_npy )
  plt.plot(array_k8_rloss_npy )
  plt.plot(array_k4_rloss_npy)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Loss function for various RSSI')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  plt.legend(['K=32', 'K=16','K=8','K=4'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/loss.png",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(z32)
  plt.plot(z16 )
  plt.plot(z8 )
  plt.plot(z4)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Efficiency for various RSSI bits')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  #plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/normalized.png",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(zn1[5:500])
  plt.plot(zn2[5:500] )
  plt.plot(zn3 [5:500])
  #plt.plot(array_k4_rpre_npy)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Normalized sum-rate for different noise')
  plt.ylabel('Normalized Value')
  plt.xlabel('Epochs')
  plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/noisenorm.png",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(acc32)
  plt.plot(acc16 )
  plt.plot(acc8 )
  plt.plot(acc4)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Accuracy measurement for various RSSI')
  plt.ylabel('Accuracy')
  plt.xlabel('Epochs')
  plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/accuracy",  dpi=400)
  plt.show()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
import math
with torch.no_grad():
  plt.plot(k5,h5,marker='*')
  #plt.xticks('4','8','16','32')
  ax = plt.axes()
  ax.set_xticks([4,8,16,32])
  #plt.plot(array_k16_rpre_npy )
  #plt.plot(array_k8_rpre_npy )
  #plt.plot(array_k4_rpre_npy)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Achievable sum-rate for various RSSI bits')
  plt.ylabel('Sum-rate')
  plt.xlabel('RSSI bits')
  #plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/RSSIup.png",  dpi=400)
  plt.show()
# Out:
# <ipython-input-9-1980e33e1ebc>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %%
#x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
import math
with torch.no_grad():
  plt.plot(snr5,p5,marker='*')
  #plt.xticks('4','8','16','32')
  ax = plt.axes()
  ax.set_xticks([120,125,130])
  #plt.plot(array_k16_rpre_npy )
  #plt.plot(array_k8_rpre_npy )
  #plt.plot(array_k4_rpre_npy)
  #plt.plot(X, z, color='g', label='cos')
  plt.title('Optimum sum-rate for various Noise Power')
  plt.ylabel('Sum-rate')
  plt.xlabel('Noise Power dB(-σ²)')
  #plt.legend(['K=4', 'K=8','K=16','K=32'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/Figure/upsnr.png",  dpi=400)
  plt.show()
# Out:
# <ipython-input-28-588bc7114fcc>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %%
plt.plot(k5,h5)
#plt.set_xticks([0,2,4,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
#x = np.arange(0, math.pi*2, 0.05)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
#y = np.sin(x)
ax.plot(k5, h5)
ax.set_xlabel('angle')
ax.set_title('')
ax.set_xticks([4,8,16,32])
#ax.set_xticklabels(['zero','two','four','six'])
#ax.set_yticks([-1,0,1])
plt.show()

# %%
plt.plot([array_k8_rpre_npy,array_k16_rpre_npy])

# %%
import numpy as np 
import matplotlib.pyplot as plt



plt.imshow(h6, interpolation='none')
plt.show()

# %%
import numpy as np
array_nor2_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/nor2_rpre.npy")

# %%
import numpy as np
array_noise1_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/noise1_rpre.npy")

# %%
import numpy as np
array_noise2_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/noise2_rpre.npy")

# %%
import numpy as np
array_noise3_rpre_npy = np.load("/content/drive/MyDrive/HBF-Net-main/noise3_rpre.npy")

# %%
import numpy as np
array_nor3_rop_npy = np.load("/content/drive/MyDrive/HBF-Net-main/nor3_r_op.npy")

# %%
x1 = array_nor2_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
print(max(x1))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(x1)
  plt.title('Achievable sum-rate for Nu=4')
  plt.ylabel('Sum-rate')
  plt.xlabel('Epochs')
  #plt.legend(['Train', 'Validation'], loc='center right')
  plt.savefig("/content/drive/MyDrive/HBF-Net-main/sumnor2.png",  dpi=400)
  plt.show()
# Out:
# 5.0699196

# %%
#x2 = array_nor3_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x2))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(y[:20,:20])
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
from numpy.lib.npyio import zipfile_factory
import numpy as np
x = array_nor3_rpre_npy

y = array_nor3_rop_npy
z=x/y
a=np.array(x)
a1=np.max(a)
b1=np.min(a)
c=np.array(y)
a12=np.max(c)
b12=np.min(c)
z1=(a-b1)/(a1-b1)
z2=(a-b12)/(a12-b12)
print(z)
#print(b)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(z)
  plt.show()
# Out:
# [0.33504686 0.5358473  0.6018775  0.63223165 0.6631902  0.69424397
#  0.7173152  0.73566306 0.7497667  0.7617876  0.7717905  0.7794516
#  0.7872796  0.79412436 0.8003794  0.80510676 0.8096618  0.81428504
#  0.81801254 0.82113546 0.82421887 0.82699555 0.8295554  0.8316608
#  0.8338913  0.8359049  0.83782846 0.83972585 0.8414499  0.84305185
#  0.8446649  0.84627557 0.8477263  0.8491602  0.8504377  0.85157305
#  0.8527835  0.85372865 0.85489243 0.8559846  0.85704017 0.8579882
#  0.85862136 0.8592492  0.8600337  0.86084354 0.86153543 0.8622571
#  0.8629697  0.86370873 0.86433506 0.86501473 0.86568195 0.8662846
#  0.8669136  0.8675175  0.8680741  0.8686183  0.8691681  0.86970556
#  0.8702104  0.8707067  0.8711853  0.8716765  0.87210983 0.8725769
#  0.8730283  0.87347454 0.8739118  0.87431777 0.8747341  0.8751346
#  0.8755316  0.87592226 0.876309   0.87668616 0.8770562  0.87738866
#  0.8777354  0.87808496 0.87842214 0.8787258  0.87905097 0.87937105
# ...

# %%
x2 = array_nor3_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
print(max(x2))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(x2)
  plt.show()
# Out:
# 4.7993965

# %%
x3 = array_noise1_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
print(max(x3))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(x3)
  plt.show()
# Out:
# 4.7813106

# %%
x5 = array_noise3_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
print(max(x5))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(x5)
  plt.show()
# Out:
# 4.4632344

# %%
import numpy as np
f= np.load('/content/drive/MyDrive/HBF-Net-main/DataBase_dataSet64x8x4_130dB_0129201820.npy')
f.shape
#mu, sigma = 0, np.std(f)*0.04
#noise = np.random.normal(mu, sigma, f.shape)
#noise.shape
y5=np.std(f)

# %%
print(f.shape)
# Out:
# (10080, 1449)

# %%
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()

#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(f[1:10,1:10])
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
target_snr_db = 20
# Calculate signal power and convert to dB 
sig_avg_watts = np.mean(x_watts)
sig_avg_db = 10 * np.log10(sig_avg_watts)
# Calculate noise according to [2] then convert to watts
noise_avg_db = sig_avg_db - target_snr_db
noise_avg_watts = 10 ** (noise_avg_db / 10)
# Generate an sample of white noise
mean_noise = 0
noise_volts = np.random.normal(mean_noise, np.sqrt(noise_avg_watts), len(x_watts))
# Noise up the original signal
y_volts = x_volts + noise_volts

# %%
target_snr_db = 135
# Calculate signal power and convert to dB 
sig_avg_watts = np.mean(f)
sig_avg_db = 10 * np.log10(sig_avg_watts)
# Calculate noise according to [2] then convert to watts
noise_avg_db = sig_avg_db - target_snr_db
noise_avg_watts = 10 ** (noise_avg_db / 10)
# Generate an sample of white noise
mean_noise = 0
#noise_volts = np.random.normal(mean_noise, np.sqrt(noise_avg_watts), len(f))
mu, sigma = 0, np.std(noise_avg_watts)*0.04
noise = np.random.normal(mu, sigma, f.shape)
# Noise up the original signal
y_volts = f + noise
y_volts.shape
# Out:
# (10080, 1449)

# %%
#x2 = array_nor3_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x2))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(f[:5,:5])
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#x2 = array_nor3_rpre_npy
#x1 =array_rain_fall_npy
#y = nor2_rop
#a=x.detach().numpy()
#b=y.detach().numpy() 
#z=predicted[:20]
#y_score = z.detach().numpy()
#print(max(x2))
#print(y)
#nn_fpr, nn_tpr, nn_thresholds = roc_curve(a, y_score)
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(y_volts[:5,:5])
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
noise = np.random.normal(0, .1, f.shape)
f1 = f + noise
import torch
import matplotlib.pyplot as plt
with torch.no_grad():
  plt.plot(f1[:30,:30])
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import seaborn as sns
 
# loading dataset
data = f
 
# draw lineplot
sns.lineplot( data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-b19dfa75e6ca> in <module>
#       5
#       6 # draw lineplot
# ----> 7 sns.lineplot( data=data)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ...

# %%
import mat73
import numpy as np
D =  mat73.loadmat("/content/drive/MyDrive/Raw_Data_BS32_2p4GHz_1Path.mat")
#data_dict = mat73.loadmat('data.mat')
g=np.array(D)
type(g)
#np.save("/content/drive/MyDrive/HBF-Net-main/raw32_2p4.npy", g)
k=np.load("/content/drive/MyDrive/HBF-Net-main/raw32_2p4.npy",allow_pickle=True)
print(k['dataset'].shape)
#type(k)
#array_nor2_rop_npy = np.load("135db32op.npy")

#print(array_nor2_rop_npy)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-75f7c195ebae> in <module>
#       7 #np.save("/content/drive/MyDrive/HBF-Net-main/raw32_2p4.npy", g)
#       8 k=np.load("/content/drive/MyDrive/HBF-Net-main/raw32_2p4.npy",allow_pickle=True)
# ----> 9 print(k['dataset'].shape)
#      10 #type(k)
#      11 #array_nor2_rop_npy = np.load("135db32op.npy")
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import numpy as np
import scipy.io
import numpy as np
#import tensorflow as tf
import torch
file1=np.load('/content/drive/MyDrive/HBF-Net-main/DataBase_dataSet64x8x4_130dB_0129201820.npy')
#print(file1)


#print(a)
file_path = '/content/drive/MyDrive/mimo/130dB_0129201820.mat'
scipy.io.savemat(file_path, {'data': file1})

# %%
pip install mat73
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import mat73
import numpy as np
a1 =mat73.loadmat('/content/drive/MyDrive/mimo/new data/channel.mat')
a2 =np.array(a1['newVariable'])
a3=a2.reshape(1024,64)
print(a2.shape)
#file='/content/drive/MyDrive/HBF-Net-main/gencnl.npy'
#np.save(file, a3)
# Out:
# (32, 32, 64)

# %%
import numpy as np
#file1=np.load('/content/drive/MyDrive/HBF-Net-main/upro_channel_BS32_2p4GHz_1Path.npy')
#file2=np.load('/content/drive/MyDrive/mimo/test/channel_measurement_000000.npy')
file3=np.load('/content/drive/MyDrive/HBF-Net-main/pcaorpca.npy')
a4=np.abs(file3)
a5=np.max(a4)
a6=np.min(a4)
a7=(a4-a6)/(a5-a6)
print(a7)
# Out:
# [[1.85412261e-05 1.85412210e-05 1.85412270e-05 ... 9.60907037e-01
#   4.57432175e-01 9.60297402e-01]
#  [4.03418874e-05 4.03418935e-05 4.03418876e-05 ... 9.36484518e-01
#   4.45785893e-01 9.35890353e-01]
#  [4.26341632e-05 4.26341702e-05 4.26341633e-05 ... 9.47038340e-01
#   4.50806223e-01 9.46437475e-01]
#  ...
#  [4.79642474e-05 4.79642541e-05 4.79642475e-05 ... 9.60475138e-01
#   4.57202123e-01 9.59865747e-01]
#  [1.68361009e-05 1.68361070e-05 1.68361011e-05 ... 9.53044560e-01
#   4.53676552e-01 9.52439898e-01]
#  [1.77666933e-05 1.77666899e-05 1.77666943e-05 ... 9.51199429e-01
#   4.52809144e-01 9.50595951e-01]]

# %%
import mat73
import numpy as np
import scipy.io as sio
file2=mat73.loadmat('/content/drive/MyDrive/HBF-Net-main/newres/pcaorpca.mat')
file3=np.array(file2['newVariable'])
print(file3.shape)
file='/content/drive/MyDrive/HBF-Net-main/pcaor.npy'
np.save(file, file3)
# Out:
# (10080, 1449)

# %%
import numpy as np
y=np.load("/content/drive/MyDrive/HBF-Net-main/DataBase_dataSet64x8x4_130dB_0129201820.npy")

# %%
RSSI_N1= y[:, (Us * Mr) + (Us * K):(Us * Mr) + (2 * Us * K)].real.astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-34a62ed1a1c7> in <module>
# ----> 1 RSSI_N1= y[:, (Us * Mr) + (Us * K):(Us * Mr) + (2 * Us * K)].real.astype(float)
#
# NameError: name 'Us' is not defined

# %%
import scipy.io
import numpy as np
#x= w_prer
#y= w_prei
#a=x.detach().numpy()

#print(a)
file_path = '/content/drive/MyDrive/HBF-Net-main/newres/ordata130.mat'
scipy.io.savemat(file_path, {'data': y})

# %%
import scipy.io as sio
#import mat73
import numpy as np
#D =  mat73.loadmat("/content/drive/MyDrive/Raw_Data_BS32_2p4GHz_1Path.mat")
mat = sio.loadmat("/content/drive/MyDrive/HBF-Net-main/newres/pcaorpca.mat") # insert your filename here
#print(mat) # find the fieldname you're looking for
mat_load = mat['newVariable']
#mat_x =mat_load.transpose()
#mat_x1 =mat_x[:10080,:]
# insert your fieldname here
#print(mat.shape) # create an empty list

 # visually confirm that the output is a NumPy array
#file='/content/drive/MyDrive/HBF-Net-main/nup1_channel_BS32_2p4GHz_1Path.npy'
#np.save(file, mat_load)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-6-6f4af8d9ce4a> in <module>
#       3 import numpy as np
#       4 #D =  mat73.loadmat("/content/drive/MyDrive/Raw_Data_BS32_2p4GHz_1Path.mat")
# ----> 5 mat = sio.loadmat("/content/drive/MyDrive/HBF-Net-main/dataset/pca32cnlzpca.mat") # insert your filename here
#       6 #print(mat) # find the fieldname you're looking for
#       7 mat_load = mat['newVariable']
#
# /usr/local/lib/python3.8/dist-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     223     variable_names = kwargs.pop('variable_names', None)
#     224     with _open_file_context(file_name, appendmat) as f:
# --> 225         MR, _ = mat_reader_factory(f, **kwargs)
#     226         matfile_dict = MR.get_variables(variable_names)
#     227
#
# ...

# %%
# jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000000
import scipy.io as sio
import mat73
import numpy as np
#D =  mat73.loadmat("/content/drive/MyDrive/Raw_Data_BS32_2p4GHz_1Path.mat")
mat = mat73.loadmat('/content/drive/MyDrive/Raw_Data_BS32_2p4GHz_1Path.mat') # insert your filename here
print(mat) # find the fieldname you're looking for
mat_load = [[element for element in upperElement] for upperElement in mat['dataset']] # insert your fieldname here
mat_list = [] # create an empty list
length = 100 # update with the number of values you want/need...
for i in range(length): # ...or just hardcode it here
    mat_list.append(mat_load[i][0]) # append the values to the list
np_array = np.array(mat_list) # convert the list to a NumPy array
int32_array = np_array.astype(np.int32) # convert values to int32
int32_array # visually confirm that the output is a NumPy array
# Out:
# {'dataset': {'channels': array([[ 1.4809840e-03-0.00048635j,  1.5565692e-03+0.00011326j,
#          1.3986441e-03+0.00069677j, ...,  1.0983900e-03+0.00022555j,
#          1.1007391e-03+0.00021365j,  1.1030831e-03+0.00020106j],
#        [ 1.5488474e-03+0.00017585j,  1.3670085e-03+0.00075301j,
#          9.7914878e-04+0.00121777j, ..., -1.1056892e-03+0.0001865j ,
#         -1.1035707e-03+0.00019851j, -1.1011913e-03+0.00021117j],
#        [ 1.3342525e-03+0.00080599j,  9.2757936e-04+0.00125512j,
#          3.8023284e-04+0.00151562j, ...,  9.6363365e-04-0.00057336j,
#          9.5728540e-04-0.00058385j,  9.5045188e-04-0.00059486j],
#        ...,
#        [-1.2981510e-03-0.00086294j, -8.0986938e-04-0.00133411j,
#         -1.6075312e-04-0.0015543j , ...,  5.1446189e-04-0.00099632j,
#          4.9775769e-04-0.00100474j,  4.7980994e-04-0.00101341j],
#        [-8.1976841e-04-0.00132583j, -1.7866143e-04-0.00155042j,
#          5.0390104e-04-0.00147911j, ..., -1.1977242e-04+0.00111489j,
# ...

# %%
import mat73
import numpy as np
import scipy.io as sio
import pandas as pd
file2=sio.loadmat('/content/drive/MyDrive/Beam-Prediction-main/MATLAB Files/UPA_codebook.mat')
data_array1 = file2['x']
data_array2 =np.reshape(data_array1,(4,1024))
data_array4 = data_array2[:,1:513]
data_array3 = pd.DataFrame(data_array4)


print(data_array3.shape)
#data_array3.to_csv("/content/drive/MyDrive/HBF-Net-main/Codebook/example2.csv")
# Out:
# (4, 512)

# %%
import pandas as pd
data = pd.read_csv("//content/drive/MyDrive/HBF-Net-main/Codebook/example2.csv")
data[:2,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-4405f0eadf29> in <module>
#       1 import pandas as pd
#       2 data = pd.read_csv("//content/drive/MyDrive/HBF-Net-main/Codebook/example2.csv")
# ----> 3 data[:2,:]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
# ...

# %%
import pandas as pd
import numpy as np
import scipy.io
data = pd.read_csv("/content/drive/MyDrive/HBF-Net-main/Codebook/Codebook_ij.csv")
data1=np.array(data)
file_path = '/content/drive/MyDrive/mimo/orcb.mat'
scipy.io.savemat(file_path, {'data': data1})

# %%
import os
import numpy as np
path = '/content/drive/MyDrive/mimo/test/'
trainImages = []
for i in os.listdir(path):
  data = np.load(path+i)
  trainImages.append(data)

# %%
print(np.array(trainImages).shape)
a3 =
#file='/content/drive/MyDrive/mimo/DIS_lab_LoS/dism6erge.npy'
#np.save(file, trainImages)
# Out:
# (12, 64, 100)

# %%
d1 =np.array(trainImages)
print(d1.shape)
d2=d1.reshape(-1)
d3=d2[1:14605921]
d4=d3.reshape(10080,1449)
print(d4.shape)
file='/content/drive/MyDrive/mimo/ULA_lab_LoS/ulam6erge.npy'
np.save(file, trainImages)
# Out:
# (5130, 64, 100)
# (10080, 1449)

# %%
import numpy as np
import scipy.io
import numpy as np
#import tensorflow as tf
import torch
file1=np.load('/content/drive/MyDrive/mimo/DIS_lab_LoS/dism6erge.npy')
#print(file1)


#print(a)
file_path = '/content/drive/MyDrive/mimo/dislablos.mat'
scipy.io.savemat(file_path, {'data': file1})
